# %%
# Clone repository từ GitHub
# !git clone https://github.com/Nguyen-Phuong-Nguyen/GraphFVD.git

# Di chuyển vào thư mục dự án
# %cd GraphFVD
# Out:
# Cloning into 'GraphFVD'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 109 (delta 44), reused 96 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 46.08 KiB | 4.61 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /kaggle/working/GraphFVD

# %%
# !pip install transformers==4.36.0 tokenizers==0.15.0 torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 105.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# # 1. Gỡ sạch các bản cũ
# !pip uninstall torch torchvision torchaudio torchdata dgl -y

# # 2. Cài lại bộ combo ổn định (CUDA 12.1 tương thích tốt nhất với các thư viện này)
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 torchdata==0.7.1 --index-url https://download.pytorch.org/whl/cu121

# # 3. Cài DGL khớp với torch 2.4.0
# !pip install dgl -f https://data.dgl.ai/wheels/cu121/repo.html

# %%
# !python /kaggle/working/GraphFVD/dataset/my_preprocess.py
# Out:
# Reading data from: /kaggle/input/graphfvd-nvd-dataset/NVD/NVD_PrVCs.json
# Saved to /kaggle/working/GraphFVD/dataset/NVD/my_train.jsonl
# Saved to /kaggle/working/GraphFVD/dataset/NVD/my_valid.jsonl
# Saved to /kaggle/working/GraphFVD/dataset/NVD/my_test.jsonl
# Preprocessing completed!

# %%
# !python /kaggle/working/GraphFVD/code/run.py
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2025-12-29 08:45:49.445371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766997949.595230      75 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766997949.637838      75 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.8.0+cu126
# 12.6

# %%
import json

path = "/kaggle/working/GraphFVD/dataset/NVD/my_test.jsonl"

with open(path) as f:
    sample = json.loads(f.readline())

print(sample.keys())
# Out:
# dict_keys(['filename', 'nodes', 'edges', 'nodes_label', 'nodes_codes', 'edges_label', 'code_lines', 'vul_type', 'node_target', 'target', 'idx'])

# %%
import json

path = "/kaggle/working/GraphFVD/dataset/NVD/my_train.jsonl"

keys_set = set()
with open(path) as f:
    for i in range(100):  # kiểm tra 100 dòng đầu
        js = json.loads(f.readline())
        keys_set.update(js.keys())

print(sorted(keys_set))
# Out:
# ['code_lines', 'edges', 'edges_label', 'filename', 'idx', 'node_target', 'nodes', 'nodes_codes', 'nodes_label', 'target', 'vul_type']
